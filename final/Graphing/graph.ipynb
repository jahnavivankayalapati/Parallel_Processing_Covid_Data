# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Covid Dataset - Priyanka, Jahnavi

# %%
# Data from the output
# models = ["Standard RF", "Multiprocessing RF", "MPI RF"]
models = ["Control", "Multiprocessing", "MPI"]
training_times = [0.1133, 0.40819358825683594, 0.0310]
# training_times = [2.7241, 0.2511, 1.0849]
# testing_times = [0.0178, 0.0138, 0.0056]
# accuracies = [66.86, 57.26, 65.61]

# %%
# Plot Training Time
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 3, 1)
plt.bar(models, training_times, color=['blue', 'orange', 'green'])
plt.title("Training Time (seconds)")
plt.ylabel("Time (s)")
plt.xlabel("Model")
# plt.ylim(0, max(training_times) * 1.2)
# # Plot Testing Time
# plt.subplot(1, 3, 2)
# plt.bar(models, testing_times, color=['blue', 'orange', 'green'])
# plt.title("Testing Time (seconds)")
# plt.ylabel("Time (s)")
# plt.xlabel("Model")
# plt.ylim(0, max(testing_times) * 1.2)
# # Plot Accuracy
# plt.subplot(1, 3, 3)
# plt.bar(models, accuracies, color=['blue', 'orange', 'green'])
# plt.title("Accuracy (%)")
# plt.ylabel("Accuracy (%)")
# plt.xlabel("Model")
# plt.ylim(0, 100)
# # Adjust layout
# plt.tight_layout()
# plt.show()
# Out:
# Text(0.5, 0, 'Model')

# %% [markdown]
# ### Open Covid Data - Nathan

# %%
# Data from the output
models = ["Control", "Multiprocessing", "MPI"]
training_times = [585.6923, 8.448691129684448, 11.9158]

# %%
# Plot Training Time
plt.bar(models, training_times, color=['blue', 'orange', 'green'])
plt.title("Training Time on Dataset 2 - 32 Processors")
plt.ylabel("Time (s)")
plt.xlabel("Model")
# plt.ylim(0, max(training_times) * 1.2)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Zoom in
plt.bar(models, training_times, color=['blue', 'orange', 'green'])
plt.title("Training Time on Dataset 2 - 32 Processors")
plt.ylabel("Time (s)")
plt.xlabel("Model")
plt.ylim(0, 30)

# Adjust layout
plt.tight_layout()
plt.show()
